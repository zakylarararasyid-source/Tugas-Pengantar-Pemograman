# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def my_line(x, m, q):
    y = m * x + q
    return y

my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_majors', engine='openpyxl')

my_dataset3 = my_dataset[my_dataset.Epoch == 'three']

x = np.linspace(51, 65, 120)
y = my_line(x, m= 0, q=7)

line_settings = {'m':0.28,'q':-9.5,'color':'#1f618d'}
figure_settings = {'width':9, 'height':6}
marker_settings = {'alpha':0.7, 'size':40}

fig, ax = plt.subplots(figsize=(9,6))

ax.scatter(my_dataset1.SiO2, my_dataset1.K2O, marker='o', color="#d19ee1", s=35, alpha=0.75, label='Epoch 1')
ax.scatter(my_dataset2.SiO2, my_dataset2.K2O, marker='o', color='#fb6a4a', s=35, alpha=0.75, label='Epoch 2')
ax.scatter(my_dataset3.SiO2, my_dataset3.K2O, marker='o', color='#2ECC71', s=40, alpha=0.7, label='High SiO2')
ax.plot(x, y, color='#2c3e50', linewidth=2)

ax.text(54,6.5, r'$Na_20 = 0.34 \cdot SiO_2 - 12.1$', rotation=34)
ax.text(58,5.2, r'$\mu_{SiO_2}=58.3\,[wt.\%]$')

ax.set_xlabel(r'SiO$_2$ [wt%]')
ax.set_ylabel(r'K$_2$O [wt%]')

ax.legend(loc='upper left')

plt.show()
